# %%
import os
import ipyvolume as ipv
import tyssue
import json
import matplotlib.pylab as plt
import numpy as np
import pandas as pd
import random
import sys
import logging
import tyssue.io.hdf5 as hdf5
from IPython.display import Image
from scipy import optimize
from tyssue.draw import sheet_view

from tyssue import Sheet
from tyssue import SheetGeometry

##### Own functions
import src.cellDivisionOld as cellDivisionOld
import src.cellDivision as cellDivision
import src.vertexModel as vertexModel
import src.inputMechanicalParameters as inputMechanicalParameters
import src.auxFunctions as auxFunctions
from tyssue.topology import add_vert

from tyssue.draw.plt_draw import create_gif
from tyssue.draw import highlight_faces, create_gif
from IPython.display import Image

from tyssue.topology.base_topology import add_vert, close_face, collapse_edge, remove_face
from tyssue.topology.base_topology import split_vert as base_split_vert

from matplotlib import cm
from matplotlib.cm import ScalarMappable
from mpl_toolkits.axes_grid1 import make_axes_locatable
import matplotlib.colors as mcolors

from math import sqrt
from scipy.optimize import curve_fit
from scipy.stats import ttest_ind
import json

import pickle 
import gzip

import imageio

import logging
logger = logging.getLogger(name=__name__)

import warnings
warnings.filterwarnings("ignore")
#
# Out:
# collision solver could not be imported You may need to install CGAL and re-install tyssue

# %%
combined_gif_path = cellDivision.div_longest_vert_collapse_random_edge_fixed_border('fixed_boundary_div_longest_vert_collapse_random_edge', 100, 6, 0.1)
# Out:
# CGAL-based mesh generation utilities not found, you may need to install CGAL and build from source
# C++ extensions are not available for this version
# Cycle 1 started.
# Collapsing random edge: 1258
# Number of edges connected to srce_vertex (338.0): 6
# Number of edges connected to trgt_vertex (337.0): 6
# Dropped chosen edge 1258 and its opposite edge 1257.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 1015
# Connected edges before reassignment: [2040, 2041, 2044, 2045, 4033, 4034]
# All edges assigned to right vertex 2761: [2044, 2045, 8135, 8136]
# All edges assigned to left vertex 1015: [2040, 2041, 4033, 4034, 8135, 8136]
# Topology changed!
# Cycle 2 started.
# Collapsing random edge: 7035
# Number of edges connected to srce_vertex (2499.0): 6
# Number of edges connected to trgt_vertex (2190.0): 6
# Dropped chosen edge 7035 and its opposite edge 7034.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2758
# Connected edges before reassignment: [1255, 1256, 1257, 1258, 1357, 1358, 1359, 1360]
# All edges assigned to right vertex 2761: [1255, 1256, 1257, 1258, 8135, 8136]
# All edges assigned to left vertex 2758: [1357, 1358, 1359, 1360, 8135, 8136]
# Topology changed!
# Cycle 3 started.
# Collapsing random edge: 3004
# Number of edges connected to srce_vertex (1335.0): 6
# Number of edges connected to trgt_vertex (1336.0): 6
# Dropped chosen edge 3004 and its opposite edge 3005.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 1647
# Connected edges before reassignment: [5450, 5451, 5452, 5453, 6621, 6622]
# All edges assigned to right vertex 2761: [5450, 5451, 5452, 5453, 8135, 8136]
# All edges assigned to left vertex 1647: [6621, 6622, 8135, 8136]
# Topology changed!
# Cycle 4 started.
# Collapsing random edge: 7752
# Number of edges connected to srce_vertex (2685.0): 6
# Number of edges connected to trgt_vertex (2686.0): 6
# Dropped chosen edge 7752 and its opposite edge 7753.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [7740, 7741, 7744, 7745, 7750, 7751, 8004, 8005]
# All edges assigned to right vertex 2760: [7740, 7741, 7744, 7745, 8135, 8136]
# All edges assigned to left vertex 2761: [7750, 7751, 8004, 8005, 8135, 8136]
# Topology changed!
# Cycle 5 started.
# Collapsing random edge: 6253
# Number of edges connected to srce_vertex (2289.0): 6
# Number of edges connected to trgt_vertex (2291.0): 6
# Dropped chosen edge 6253 and its opposite edge 6254.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 1150
# Connected edges before reassignment: [3636, 3637, 3638, 3639, 4293, 4294]
# All edges assigned to right vertex 1150: [3638, 3639, 8135, 8136]
# All edges assigned to left vertex 2761: [3636, 3637, 4293, 4294, 8135, 8136]
# Topology changed!
# Cycle 6 started.
# Collapsing random edge: 3383
# Number of edges connected to srce_vertex (1430.0): 6
# Number of edges connected to trgt_vertex (798.0): 6
# Dropped chosen edge 3383 and its opposite edge 3382.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [3368, 3369, 3370, 3371, 3380, 3381, 3404, 3405]
# All edges assigned to right vertex 2761: [3368, 3369, 3370, 3371, 8135, 8136]
# All edges assigned to left vertex 2760: [3380, 3381, 3404, 3405, 8135, 8136]
# Topology changed!
# Cycle 7 started.
# Collapsing random edge: 3366
# Number of edges connected to srce_vertex (1426.0): 6
# Number of edges connected to trgt_vertex (1427.0): 6
# Dropped chosen edge 3366 and its opposite edge 3367.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2358
# Connected edges before reassignment: [6495, 6496, 6497, 6498, 6511, 6512]
# All edges assigned to right vertex 2358: [6495, 6496, 8135, 8136]
# All edges assigned to left vertex 2761: [6497, 6498, 6511, 6512, 8135, 8136]
# Topology changed!
# Cycle 8 started.
# Collapsing random edge: 7158
# Number of edges connected to srce_vertex (2296.0): 6
# Number of edges connected to trgt_vertex (2523.0): 6
# Dropped chosen edge 7158 and its opposite edge 7159.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [6299, 6300, 6301, 6302, 7146, 7147, 7148, 7149]
# All edges assigned to right vertex 2760: [7146, 7147, 7148, 7149, 8135, 8136]
# All edges assigned to left vertex 2761: [6299, 6300, 6301, 6302, 8135, 8136]
# Topology changed!
# Cycle 9 started.
# Collapsing random edge: 7992
# Number of edges connected to srce_vertex (2743.0): 6
# Number of edges connected to trgt_vertex (2745.0): 6
# Dropped chosen edge 7992 and its opposite edge 7993.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 1502
# Connected edges before reassignment: [3630, 3631, 3638, 3639, 3640, 3641]
# All edges assigned to right vertex 2761: [3640, 3641, 8135, 8136]
# All edges assigned to left vertex 1502: [3630, 3631, 3638, 3639, 8135, 8136]
# Topology changed!
# Cycle 10 started.
# Collapsing random edge: 1385
# Number of edges connected to srce_vertex (350.0): 6
# Number of edges connected to trgt_vertex (768.0): 6
# Dropped chosen edge 1385 and its opposite edge 1386.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2744
# Connected edges before reassignment: [5813, 5814, 5815, 5816, 7024, 7025, 7478, 7479]
# All edges assigned to right vertex 2744: [7024, 7025, 7478, 7479, 8135, 8136]
# All edges assigned to left vertex 2761: [5813, 5814, 5815, 5816, 8135, 8136]
# Topology changed!
# Cycle 11 started.
# Collapsing random edge: 3026
# Number of edges connected to srce_vertex (1338.0): 6
# Number of edges connected to trgt_vertex (1339.0): 6
# Dropped chosen edge 3026 and its opposite edge 3027.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [3022, 3023, 3026, 3027, 3030, 3031, 3036, 3037]
# All edges assigned to right vertex 2760: [3030, 3031, 3036, 3037, 8135, 8136]
# All edges assigned to left vertex 2761: [3022, 3023, 3026, 3027, 8135, 8136]
# Topology changed!
# Cycle 12 started.
# Collapsing random edge: 665
# Number of edges connected to srce_vertex (512.0): 6
# Number of edges connected to trgt_vertex (511.0): 6
# Dropped chosen edge 665 and its opposite edge 664.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2750
# Connected edges before reassignment: [3358, 3359, 3360, 3361, 3364, 3365, 3368, 3369]
# All edges assigned to right vertex 2761: [3358, 3359, 3364, 3365, 8135, 8136]
# All edges assigned to left vertex 2750: [3360, 3361, 3368, 3369, 8135, 8136]
# Topology changed!
# Cycle 13 started.
# Collapsing random edge: 7079
# Number of edges connected to srce_vertex (1896.0): 6
# Number of edges connected to trgt_vertex (1895.0): 6
# Dropped chosen edge 7079 and its opposite edge 7078.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [6159, 6160, 6165, 6166, 7078, 7079, 7858, 7859]
# All edges assigned to right vertex 2761: [6159, 6160, 6165, 6166, 7858, 7859, 8135, 8136]
# All edges assigned to left vertex 2760: [7078, 7079, 8135, 8136]
# Topology changed!
# Cycle 14 started.
# Collapsing random edge: 1995
# Number of edges connected to srce_vertex (1002.0): 6
# Number of edges connected to trgt_vertex (473.0): 6
# Dropped chosen edge 1995 and its opposite edge 1994.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2759
# Connected edges before reassignment: [6157, 6158, 6163, 6164, 7856, 7857, 8133, 8134]
# All edges assigned to right vertex 2761: [6157, 6158, 6163, 6164, 7856, 7857, 8135, 8136]
# All edges assigned to left vertex 2759: [8133, 8134, 8135, 8136]
# Topology changed!
# Cycle 15 started.
# Collapsing random edge: 3187
# Number of edges connected to srce_vertex (1371.0): 6
# Number of edges connected to trgt_vertex (1356.0): 6
# Dropped chosen edge 3187 and its opposite edge 3186.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [3132, 3133, 3134, 3135, 3186, 3187, 4761, 4762]
# All edges assigned to right vertex 2761: [3186, 3187, 4761, 4762, 8135, 8136]
# All edges assigned to left vertex 2760: [3132, 3133, 3134, 3135, 8135, 8136]
# Topology changed!
# Cycle 16 started.
# Collapsing random edge: 7844
# Number of edges connected to srce_vertex (2625.0): 6
# Number of edges connected to trgt_vertex (2691.0): 6
# Dropped chosen edge 7844 and its opposite edge 7845.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 1425
# Connected edges before reassignment: [5043, 5044, 5045, 5046, 6137, 6138]
# All edges assigned to right vertex 2761: [5043, 5044, 6137, 6138, 8135, 8136]
# All edges assigned to left vertex 1425: [5045, 5046, 8135, 8136]
# Topology changed!
# Cycle 17 started.
# Collapsing random edge: 6031
# Number of edges connected to srce_vertex (740.0): 6
# Number of edges connected to trgt_vertex (2223.0): 6
# Dropped chosen edge 6031 and its opposite edge 6032.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2732
# Connected edges before reassignment: [2996, 2997, 2998, 2999, 3006, 3007, 3008, 3009]
# All edges assigned to right vertex 2732: [2996, 2997, 3006, 3007, 8135, 8136]
# All edges assigned to left vertex 2761: [2998, 2999, 3008, 3009, 8135, 8136]
# Topology changed!
# Cycle 18 started.
# Collapsing random edge: 6137
# Number of edges connected to srce_vertex (2244.0): 6
# Number of edges connected to trgt_vertex (2245.0): 6
# Dropped chosen edge 6137 and its opposite edge 6138.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [6137, 6138, 6139, 6140, 6153, 6154, 6197, 6198]
# All edges assigned to right vertex 2760: [6139, 6140, 6197, 6198, 8135, 8136]
# All edges assigned to left vertex 2761: [6137, 6138, 6153, 6154, 8135, 8136]
# Topology changed!
# Cycle 19 started.
# Collapsing random edge: 3343
# Number of edges connected to srce_vertex (793.0): 6
# Number of edges connected to trgt_vertex (313.0): 6
# Dropped chosen edge 3343 and its opposite edge 3342.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [3340, 3341, 3344, 3345, 3384, 3385, 3386, 3387]
# All edges assigned to right vertex 2760: [3340, 3341, 3384, 3385, 8135, 8136]
# All edges assigned to left vertex 2761: [3344, 3345, 3386, 3387, 8135, 8136]
# Topology changed!
# Cycle 20 started.
# Collapsing random edge: 1309
# Number of edges connected to srce_vertex (755.0): 6
# Number of edges connected to trgt_vertex (759.0): 6
# Dropped chosen edge 1309 and its opposite edge 1310.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2617
# Connected edges before reassignment: [7536, 7537, 7538, 7539, 7852, 7853]
# All edges assigned to right vertex 2617: [7852, 7853, 8135, 8136]
# All edges assigned to left vertex 2761: [7536, 7537, 7538, 7539, 8135, 8136]
# Topology changed!
# Cycle 21 started.
# Collapsing random edge: 3112
# Number of edges connected to srce_vertex (1338.0): 6
# Number of edges connected to trgt_vertex (1339.0): 6
# Dropped chosen edge 3112 and its opposite edge 3113.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [3082, 3083, 3084, 3085, 3106, 3107, 3108, 3109]
# All edges assigned to right vertex 2760: [3084, 3085, 3108, 3109, 8135, 8136]
# All edges assigned to left vertex 2761: [3082, 3083, 3106, 3107, 8135, 8136]
# Topology changed!
# Cycle 22 started.
# Collapsing random edge: 3653
# Number of edges connected to srce_vertex (1497.0): 6
# Number of edges connected to trgt_vertex (1496.0): 6
# Dropped chosen edge 3653 and its opposite edge 3652.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [3644, 3645, 3650, 3651, 4369, 4370, 4371, 4372]
# All edges assigned to right vertex 2760: [3644, 3645, 3650, 3651, 4371, 4372, 8135, 8136]
# All edges assigned to left vertex 2761: [4369, 4370, 8135, 8136]
# Topology changed!
# Cycle 23 started.
# Collapsing random edge: 1275
# Number of edges connected to srce_vertex (331.0): 6
# Number of edges connected to trgt_vertex (332.0): 6
# Dropped chosen edge 1275 and its opposite edge 1276.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [1273, 1274, 1275, 1276, 3076, 3077, 3078, 3079]
# All edges assigned to right vertex 2761: [1275, 1276, 3078, 3079, 8135, 8136]
# All edges assigned to left vertex 2760: [1273, 1274, 3076, 3077, 8135, 8136]
# Topology changed!
# Cycle 24 started.
# Collapsing random edge: 7524
# Number of edges connected to srce_vertex (2609.0): 6
# Number of edges connected to trgt_vertex (2610.0): 6
# Dropped chosen edge 7524 and its opposite edge 7525.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2756
# Connected edges before reassignment: [3642, 3643, 3648, 3649, 4369, 4370, 8131, 8132]
# All edges assigned to right vertex 2761: [3648, 3649, 8135, 8136]
# All edges assigned to left vertex 2756: [3642, 3643, 4369, 4370, 8131, 8132, 8135, 8136]
# Topology changed!
# Cycle 25 started.
# Collapsing random edge: 7296
# Number of edges connected to srce_vertex (2062.0): 6
# Number of edges connected to trgt_vertex (2531.0): 6
# Dropped chosen edge 7296 and its opposite edge 7297.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [6781, 6782, 6783, 6784, 7286, 7287, 7288, 7289]
# All edges assigned to right vertex 2761: [6783, 6784, 7288, 7289, 8135, 8136]
# All edges assigned to left vertex 2760: [6781, 6782, 7286, 7287, 8135, 8136]
# Topology changed!
# Cycle 26 started.
# Collapsing random edge: 5379
# Number of edges connected to srce_vertex (2052.0): 6
# Number of edges connected to trgt_vertex (2051.0): 6
# Dropped chosen edge 5379 and its opposite edge 5378.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!
# Dividing vertex: 2760
# Connected edges before reassignment: [5378, 5379, 5380, 5381, 5390, 5391, 5424, 5425]
# All edges assigned to right vertex 2761: [5378, 5379, 5380, 5381, 8135, 8136]
# All edges assigned to left vertex 2760: [5390, 5391, 5424, 5425, 8135, 8136]
# Topology changed!
# Cycle 27 started.
# Collapsing random edge: 1306
# Number of edges connected to srce_vertex (752.0): 6
# Number of edges connected to trgt_vertex (751.0): 6
# Dropped chosen edge 1306 and its opposite edge 1305.
# Number of edges connected to new_vertex (2762) after reassignment: 8
# Topology changed!

# %%
combined_gif_path = cellDivision.div_longest_vert_collapse_shortest_edge_fixed_border('fixed_boundary_div_longest_vert_collapse_shortest_edge_30', 30, 6, 0.1)
# Out:
# Directory created: fixed_boundary_div_longest_vert_collapse_shortest_edge_30
# CGAL-based mesh generation utilities not found, you may need to install CGAL and build from source
# C++ extensions are not available for this version
# Cycle 1 started.
# Collapsing shortest edge: 6601
# Number of edges connected to srce_vertex (856.0): 6
# Number of edges connected to trgt_vertex (1408.0): 6
# Dropped chosen edge 6601 and its opposite edge 6602.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 2766
# Connected edges before reassignment: [3213, 3214, 3215, 3216, 6595, 6596, 6599, 6600]
# All edges assigned to right vertex 2766: [6599, 6600, 8152, 8153]
# All edges assigned to left vertex 2767: [3213, 3214, 3215, 3216, 6595, 6596, 8152, 8153]
# Topology changed!
# Cycle 2 started.
# Collapsing shortest edge: 7118
# Number of edges connected to srce_vertex (2514.0): 6
# Number of edges connected to trgt_vertex (2516.0): 6
# Dropped chosen edge 7118 and its opposite edge 7119.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 2765
# Connected edges before reassignment: [3213, 3214, 3215, 3216, 6595, 6596, 8150, 8151]
# All edges assigned to right vertex 2767: [6595, 6596, 8150, 8151, 8152, 8153]
# All edges assigned to left vertex 2765: [3213, 3214, 3215, 3216, 8152, 8153]
# Topology changed!
# Cycle 3 started.
# Collapsing shortest edge: 1812
# Number of edges connected to srce_vertex (930.0): 6
# Number of edges connected to trgt_vertex (933.0): 6
# Dropped chosen edge 1812 and its opposite edge 1813.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 1060
# Connected edges before reassignment: [2182, 2183, 2184, 2185, 2202, 2203]
# All edges assigned to right vertex 1060: [2202, 2203, 8152, 8153]
# All edges assigned to left vertex 2767: [2182, 2183, 2184, 2185, 8152, 8153]
# Topology changed!
# Cycle 4 started.
# Collapsing shortest edge: 1728
# Number of edges connected to srce_vertex (381.0): 6
# Number of edges connected to trgt_vertex (384.0): 6
# Dropped chosen edge 1728 and its opposite edge 1729.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 2766
# Connected edges before reassignment: [1728, 1729, 1730, 1731, 1746, 1747, 3395, 3396]
# All edges assigned to right vertex 2767: [3395, 3396, 8152, 8153]
# All edges assigned to left vertex 2766: [1728, 1729, 1730, 1731, 1746, 1747, 8152, 8153]
# Topology changed!
# Cycle 5 started.
# Collapsing shortest edge: 5780
# Number of edges connected to srce_vertex (1363.0): 6
# Number of edges connected to trgt_vertex (1364.0): 6
# Dropped chosen edge 5780 and its opposite edge 5781.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 1138
# Connected edges before reassignment: [2464, 2465, 2466, 2467, 2482, 2483]
# All edges assigned to right vertex 1138: [2464, 2465, 2466, 2467, 8152, 8153]
# All edges assigned to left vertex 2767: [2482, 2483, 8152, 8153]
# Topology changed!
# Cycle 6 started.
# Collapsing shortest edge: 3499
# Number of edges connected to srce_vertex (1487.0): 6
# Number of edges connected to trgt_vertex (1488.0): 6
# Dropped chosen edge 3499 and its opposite edge 3500.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 1138
# Connected edges before reassignment: [2464, 2465, 2466, 2467, 8150, 8151]
# All edges assigned to right vertex 1138: [2464, 2465, 8152, 8153]
# All edges assigned to left vertex 2767: [2466, 2467, 8150, 8151, 8152, 8153]
# Topology changed!
# Cycle 7 started.
# Collapsing shortest edge: 3317
# Number of edges connected to srce_vertex (1430.0): 6
# Number of edges connected to trgt_vertex (1433.0): 6
# Dropped chosen edge 3317 and its opposite edge 3318.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 2766
# Connected edges before reassignment: [3315, 3316, 3319, 3320, 3331, 3332, 3639, 3640]
# All edges assigned to right vertex 2766: [3319, 3320, 3639, 3640, 8152, 8153]
# All edges assigned to left vertex 2767: [3315, 3316, 3331, 3332, 8152, 8153]
# Topology changed!
# Cycle 8 started.
# Collapsing shortest edge: 4945
# Number of edges connected to srce_vertex (1362.0): 6
# Number of edges connected to trgt_vertex (1916.0): 6
# Dropped chosen edge 4945 and its opposite edge 4946.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 484
# Connected edges before reassignment: [666, 667, 668, 669, 1914, 1915]
# All edges assigned to right vertex 2767: [1914, 1915, 8152, 8153]
# All edges assigned to left vertex 484: [666, 667, 668, 669, 8152, 8153]
# Topology changed!
# Cycle 9 started.
# Collapsing shortest edge: 7106
# Number of edges connected to srce_vertex (2502.0): 6
# Number of edges connected to trgt_vertex (2503.0): 6
# Dropped chosen edge 7106 and its opposite edge 7107.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 489
# Connected edges before reassignment: [672, 673, 676, 677, 2050, 2051]
# All edges assigned to right vertex 489: [2050, 2051, 8152, 8153]
# All edges assigned to left vertex 2767: [672, 673, 676, 677, 8152, 8153]
# Topology changed!
# Cycle 10 started.
# Collapsing shortest edge: 2741
# Number of edges connected to srce_vertex (1097.0): 6
# Number of edges connected to trgt_vertex (1209.0): 6
# Dropped chosen edge 2741 and its opposite edge 2742.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 2766
# Connected edges before reassignment: [2338, 2339, 2340, 2341, 2747, 2748, 2755, 2756]
# All edges assigned to right vertex 2767: [2747, 2748, 8152, 8153]
# All edges assigned to left vertex 2766: [2338, 2339, 2340, 2341, 2755, 2756, 8152, 8153]
# Topology changed!
# Cycle 11 started.
# Collapsing shortest edge: 1250
# Number of edges connected to srce_vertex (272.0): 6
# Number of edges connected to trgt_vertex (273.0): 6
# Dropped chosen edge 1250 and its opposite edge 1251.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 2766
# Connected edges before reassignment: [1246, 1247, 1250, 1251, 2320, 2321, 2330, 2331]
# All edges assigned to right vertex 2767: [1246, 1247, 2330, 2331, 8152, 8153]
# All edges assigned to left vertex 2766: [1250, 1251, 2320, 2321, 8152, 8153]
# Topology changed!
# Cycle 12 started.
# Collapsing shortest edge: 2745
# Number of edges connected to srce_vertex (1203.0): 6
# Number of edges connected to trgt_vertex (2765.0): 4
# Dropped chosen edge 2745 and its opposite edge 2746.
# Number of edges connected to new_vertex (2768) after reassignment: 6
# Topology changed!
# Dividing vertex: 2763
# Connected edges before reassignment: [2336, 2337, 2338, 2339, 2751, 2752, 8148, 8149]
# All edges assigned to right vertex 2763: [8148, 8149, 8152, 8153]
# All edges assigned to left vertex 2767: [2336, 2337, 2338, 2339, 2751, 2752, 8152, 8153]
# Topology changed!
# Cycle 13 started.
# Collapsing shortest edge: 460
# Number of edges connected to srce_vertex (376.0): 6
# Number of edges connected to trgt_vertex (383.0): 6
# Dropped chosen edge 460 and its opposite edge 461.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 2765
# Connected edges before reassignment: [2334, 2335, 2336, 2337, 2749, 2750, 8150, 8151]
# All edges assigned to right vertex 2767: [8150, 8151, 8152, 8153]
# All edges assigned to left vertex 2765: [2334, 2335, 2336, 2337, 2749, 2750, 8152, 8153]
# Topology changed!
# Cycle 14 started.
# Collapsing shortest edge: 3619
# Number of edges connected to srce_vertex (1519.0): 6
# Number of edges connected to trgt_vertex (1520.0): 6
# Dropped chosen edge 3619 and its opposite edge 3620.
# Number of edges connected to new_vertex (2768) after reassignment: 8
# Topology changed!
# Dividing vertex: 2766
# Connected edges before reassignment: [3619, 3620, 3621, 3622, 3627, 3628, 3629, 3630]
# All edges assigned to right vertex 2767: [3621, 3622, 3627, 3628, 3629, 3630, 8152, 8153]
# All edges assigned to left vertex 2766: [3619, 3620, 8152, 8153]
# Topology changed!

# %%
### carry out 10% divisions and apoptosis per cycle
